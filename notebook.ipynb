# %% [markdown]
# # Prepare and Inspect Data
#
# This notebook loads the processed multitask dataset and shows sample counts.

# %%
# !python data_processor/ag_news_data_processing.py --output_dir data/data_ag_news --max_train 10000 --max_val 2000 --max_test 3000
# !python data_processor/cola_data_processing.py --output_dir data/data_cola --max_train 10000 --max_val 2000 --max_test 3000
# !python data_processor/mnli_data_processing.py --output_dir data/data_mnli --max_train 10000 --max_val 2000 --max_test 3000
# !python data_processor/squad_data_processing.py --output_dir data/data_squad --max_train 10000 --max_val 2000 --max_test 3000
# !python data_processor/sst2_data_processing.py --output_dir data/data_sst2_v2 --max_train 10000 --max_val 2000 --max_test 3000
# !python data_processor/stsb_data_processing.py --output_dir data/data_stsb --max_train 10000 --max_val 2000 --max_test 3000
# Out:
# Saved AG News dataset to t:\NLPCK\data_ag_news
#   validation: 2,000
#   test: 3,000
#   train: 10,000
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 250675.59 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 221639.40 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 433654.26 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 433654.26 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 911765.58 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 911765.58 examples/s]
# Saved CoLA dataset to t:\NLPCK\data\data_cola
#   validation: 2,000
#   test: 3,000
#   train: 10,000
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 554838.81 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 278626.50 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 628485.69 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 628485.69 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 834255.71 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 769724.17 examples/s]
# Saved MNLI dataset to t:\NLPCK\data\data_mnli
#   validation: 2,000
#   test: 3,000
#   train: 10,000
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 375547.66 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 375547.66 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 514175.87 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 514175.87 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 901167.52 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 901167.52 examples/s]
# Saved SQuAD dataset to t:\NLPCK\data\data_squad
#   validation: 2,000
#   test: 3,000
#   train: 10,000
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 336513.48 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 288218.79 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 477838.15 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 477838.15 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 567158.06 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 567158.06 examples/s]
# Saved SST-2 dataset to t:\NLPCK\data\data_sst2_v2
#   validation: 2,000
#   test: 3,000
#   train: 10,000
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 252342.09 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 252342.09 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 529695.31 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 529695.31 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 981445.15 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 981445.15 examples/s]
# Saved STS-B dataset to t:\NLPCK\data\data_stsb
#   validation: 2,000
#   test: 3,000
#   train: 10,000
# Saving the dataset (0/1 shards):   0%|          | 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 254787.02 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 2000/2000 [00:00<00:00, 254787.02 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 280062.14 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 3000/3000 [00:00<00:00, 280062.14 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 812109.90 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 10000/10000 [00:00<00:00, 750430.12 examples/s]

# %%
from datasets import load_from_disk

ds = load_from_disk("data/data_sst2_v2")  # hoặc "data_processed"
ds1 = ds["train"]
print(ds1.shape)
ds2 = ds["validation"]
print(ds2.shape)
ds3 = ds["test"]
print(ds3.shape)
# Out:
# (10000, 3)
# (2000, 3)
# (3000, 3)

# %%
# !python merge_datasets.py --output_dir data/data_merged
# Out:
# ======================================================================
# 🔀 MERGING + SHUFFLING INDIVIDUAL TASK DATASETS
# ======================================================================
#
# 📂 Loading and merging tasks...
#   Loading sst2...
#   Loading mnli...
#   Loading cola...
#   Loading stsb...
#   Loading squad...
#   Loading ag_news...
#
# 🔀 Shuffling data (mixing tasks together)...
#   train: 60,000 samples → shuffling...
#   validation: 12,000 samples → shuffling...
#   test: 18,000 samples → shuffling...
#
# ======================================================================
# 📊 FINAL MERGED DATASET STATISTICS
# ======================================================================
# Task                Train   Validation       Test
# --------------------------------------------------
# sst2               10,000        2,000      3,000
# mnli               10,000        2,000      3,000
# cola               10,000        2,000      3,000
# stsb               10,000        2,000      3,000
# squad              10,000        2,000      3,000
# ag_news            10,000        2,000      3,000
# --------------------------------------------------
# TOTAL              60,000       12,000     18,000
# ======================================================================
#
# 🔍 CHECKING TASK DISTRIBUTION (first 100 samples of train):
# --------------------------------------------------
#   ag_news: 11 samples
#   cola: 13 samples
#   mnli: 20 samples
#   squad: 16 samples
#   sst2: 22 samples
#   stsb: 18 samples
#
# 💾 Saving merged dataset to data/data_merged...
# ✅ Merged dataset saved!
#
# 🔍 SAMPLE VALIDATION:
# --------------------------------------------------
#
#   TRAIN - first 5 samples:
#     [1] Task: sst2       | Response: positive...
#     [2] Task: ag_news    | Response: Sports...
#     [3] Task: sst2       | Response: positive...
#     [4] Task: mnli       | Response: neutral...
#     [5] Task: mnli       | Response: contradiction...
#
#   VALIDATION - first 5 samples:
#     [1] Task: mnli       | Response: entailment...
#     [2] Task: stsb       | Response: 2.0...
#     [3] Task: mnli       | Response: entailment...
#     [4] Task: cola       | Response: acceptable...
#     [5] Task: sst2       | Response: negative...
#
#   TEST - first 5 samples:
#     [1] Task: squad      | Response: the 1670s...
#     [2] Task: squad      | Response: 11–12 segments...
#     [3] Task: ag_news    | Response: World...
#     [4] Task: sst2       | Response: positive...
#     [5] Task: mnli       | Response: contradiction...
# Saving the dataset (0/1 shards):   0%|          | 0/60000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   7%|▋         | 4000/60000 [00:00<00:02, 26722.33 examples/s]
# Saving the dataset (0/1 shards):  33%|███▎      | 20000/60000 [00:00<00:00, 89687.37 examples/s]
# Saving the dataset (0/1 shards):  60%|██████    | 36000/60000 [00:00<00:00, 115110.65 examples/s]
# Saving the dataset (0/1 shards):  85%|████████▌ | 51000/60000 [00:00<00:00, 125476.30 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 60000/60000 [00:00<00:00, 125476.30 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 60000/60000 [00:00<00:00, 113983.65 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/12000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 12000/12000 [00:00<00:00, 153276.31 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 12000/12000 [00:00<00:00, 153276.31 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/18000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):  83%|████████▎ | 15000/18000 [00:00<00:00, 138540.18 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 18000/18000 [00:00<00:00, 138540.18 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 18000/18000 [00:00<00:00, 137985.66 examples/s]

# %%
# !python data_processor/ag_news_data_processing.py --output_dir data1/data_ag_news --max_train 100 --max_val 20 --max_test 30
# !python data_processor/cola_data_processing.py --output_dir data1/data_cola --max_train 100 --max_val 20 --max_test 30
# !python data_processor/mnli_data_processing.py --output_dir data1/data_mnli --max_train 100 --max_val 20 --max_test 30
# !python data_processor/squad_data_processing.py --output_dir data1/data_squad --max_train 100 --max_val 20 --max_test 30
# !python data_processor/sst2_data_processing.py --output_dir data1/data_sst2_v2 --max_train 100 --max_val 20 --max_test 30
# !python data_processor/stsb_data_processing.py --output_dir data1/data_stsb --max_train 100 --max_val 20 --max_test 30
# Out:
# Saved AG News dataset to t:\NLPCK\data1\data_ag_news
#   validation: 20
#   test: 30
#   train: 100
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map: 100%|██████████| 20/20 [00:00<00:00, 261.87 examples/s]
#
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Map: 100%|██████████| 30/30 [00:00<00:00, 664.60 examples/s]
#
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map: 100%|██████████| 100/100 [00:00<00:00, 1737.49 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3333.44 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3333.44 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 3783.20 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 3783.20 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 13672.47 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 13672.47 examples/s]
# Saved CoLA dataset to t:\NLPCK\data1\data_cola
#   validation: 20
#   test: 30
#   train: 100
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map: 100%|██████████| 20/20 [00:00<00:00, 549.33 examples/s]
#
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Map: 100%|██████████| 30/30 [00:00<00:00, 869.90 examples/s]
#
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map: 100%|██████████| 100/100 [00:00<00:00, 2159.74 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 2749.91 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 2749.91 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4530.14 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4530.14 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 25236.49 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 20092.47 examples/s]
# Saved MNLI dataset to t:\NLPCK\data1\data_mnli
#   validation: 20
#   test: 30
#   train: 100
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map: 100%|██████████| 20/20 [00:00<00:00, 463.37 examples/s]
#
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Map: 100%|██████████| 30/30 [00:00<00:00, 653.93 examples/s]
#
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map: 100%|██████████| 100/100 [00:00<00:00, 1465.32 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3313.82 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3313.82 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4089.48 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4089.48 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 13221.23 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 13221.23 examples/s]
# Saved SQuAD dataset to t:\NLPCK\data1\data_squad
#   validation: 20
#   test: 30
#   train: 100
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map: 100%|██████████| 20/20 [00:00<00:00, 333.41 examples/s]
#
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Map: 100%|██████████| 30/30 [00:00<00:00, 411.49 examples/s]
#
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map: 100%|██████████| 100/100 [00:00<00:00, 1554.47 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3403.50 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3001.94 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 35147.80 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 35147.80 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 16703.72 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 16703.72 examples/s]
# Saved SST-2 dataset to t:\NLPCK\data1\data_sst2_v2
#   validation: 20
#   test: 30
#   train: 100
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3327.49 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3327.49 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 5148.91 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4301.85 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 112057.28 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 112057.28 examples/s]
# Saved STS-B dataset to t:\NLPCK\data1\data_stsb
#   validation: 20
#   test: 30
#   train: 100
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map: 100%|██████████| 20/20 [00:00<00:00, 481.67 examples/s]
#
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Map: 100%|██████████| 30/30 [00:00<00:00, 664.78 examples/s]
#
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map: 100%|██████████| 100/100 [00:00<00:00, 1722.46 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 4149.08 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 3354.10 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 7402.15 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4367.85 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 23412.25 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 18967.59 examples/s]

# %%
# !python data_processor/ag_news_data_processing.py --output_dir data1/data_ag_news --max_train 100 --max_val 20 --max_test 30
# Out:
# Saved AG News dataset to t:\NLPCK\data1\data_ag_news
#   validation: 20
#   test: 30
#   train: 100
# Saving the dataset (0/1 shards):   0%|          | 0/20 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 2174.00 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 20/20 [00:00<00:00, 1914.42 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4650.18 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 30/30 [00:00<00:00, 4650.18 examples/s]
#
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 15832.34 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 15832.34 examples/s]
